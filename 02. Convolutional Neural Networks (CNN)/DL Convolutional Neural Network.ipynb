# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# ### Mounting Drive Containing Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Importing the libraries

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import layers

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Preprocessing the Training set

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True
)

training_set = train_datagen.flow_from_directory (
    directory = "/content/drive/MyDrive/Dataset/training_set",
    target_size = (64, 64),
    batch_size = 32,
    class_mode = 'binary'
)
# Out:
# Found 8000 images belonging to 2 classes.

# %%
training_set = tf.keras.utils.image_dataset_from_directory(
    directory = "/content/drive/MyDrive/Dataset/training_set",
    image_size = (64, 64),       # Replaces target_size
    batch_size = 32,
    label_mode = 'binary',       # Replaces class_mode
    shuffle = True               # Train data should be shuffled
)

# %% [markdown]
# ### Preprocessing the Test set

# %%
test_datagen = ImageDataGenerator(
    rescale = 1./255,
)

test_set = test_datagen.flow_from_directory (
    directory = "/content/drive/MyDrive/Dataset/test_set",
    target_size = (64, 64),
    batch_size = 32,
    class_mode = 'binary'
)
# Out:
# Found 2000 images belonging to 2 classes.

# %%
test_set = tf.keras.utils.image_dataset_from_directory(
    directory = "/content/drive/MyDrive/Dataset/test_set",
    image_size = (64, 64),       # Replaces target_size
    batch_size = 32,
    label_mode = 'binary',       # Replaces class_mode
    shuffle = False              # Test data shouldn't be shuffled
)

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Initialising the CNN

# %%
cnn = tf.keras.models.Sequential()
layers = tf.keras.layers

# %% [markdown]
# ### Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters = 32, kernel_size = 3, activation='relu', input_shape=(64, 64, 3)))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ### Step 2 - Pooling

# %%
cnn.add(layers.MaxPool2D(pool_size = 2, strides = 2))

# %% [markdown]
# ### Adding a second convolutional layer with pooling

# %%
cnn.add(tf.keras.layers.Conv2D(filters = 32, kernel_size = 3, activation='relu', input_shape=(64, 64, 3)))
cnn.add(layers.MaxPool2D(pool_size = 2, strides = 2))

# %% [markdown]
# ### Step 3 - Flattening

# %%
cnn.add(layers.Flatten())

# %% [markdown]
# ### Step 4 - Full Connection

# %%
cnn.add(layers.Dense(units = 128, activation = 'relu'))

# %% [markdown]
# ### Step 5 - Output Layer

# %%
cnn.add(layers.Dense(units = 1, activation = 'sigmoid'))

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Compiling the CNN

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1599s 6s/step - accuracy: 0.5372 - loss: 0.6914 - val_accuracy: 0.5520 - val_loss: 0.6837
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 200ms/step - accuracy: 0.6400 - loss: 0.6316 - val_accuracy: 0.6855 - val_loss: 0.5937
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 195ms/step - accuracy: 0.6890 - loss: 0.5863 - val_accuracy: 0.7265 - val_loss: 0.5581
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 52s 209ms/step - accuracy: 0.7196 - loss: 0.5517 - val_accuracy: 0.7165 - val_loss: 0.5474
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 51s 203ms/step - accuracy: 0.7365 - loss: 0.5271 - val_accuracy: 0.7500 - val_loss: 0.5179
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 53s 214ms/step - accuracy: 0.7516 - loss: 0.5015 - val_accuracy: 0.7580 - val_loss: 0.4917
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 199ms/step - accuracy: 0.7586 - loss: 0.4890 - val_accuracy: 0.7665 - val_loss: 0.5069
# Epoch 8/25
# ...

# %% [markdown]
# ## Part 4 - Making a single prediction

# %%
test_image = image.load_img('/content/drive/MyDrive/Dataset/predict_set/image.png', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices

if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'

print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# dog
